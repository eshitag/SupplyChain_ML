# %%
#Dataset link: https://www.fao.org/faostat/en/#data/FBS

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/FAOSTAT_data_en_6-5-2023.csv", encoding="ISO-8859-1")

data.shape
# Out:
# (71860, 17)

# %%
data.head()
# Out:
#   ï»¿Domain Code            Domain  Area Code (M49)         Area  \
# 0             GT  Emissions totals                4  Afghanistan
# 1             GT  Emissions totals                4  Afghanistan
# 2             GT  Emissions totals                4  Afghanistan
# 3             GT  Emissions totals                4  Afghanistan
# 4             GT  Emissions totals                4  Afghanistan
#
#    Element Code                           Element  Item Code  \
# 0          7225                   Emissions (CH4)       6991
# 1          7230                   Emissions (N2O)       6991
# 2          7273                   Emissions (CO2)       6991
# 3        724413  Emissions (CO2eq) from CH4 (AR5)       6991
# 4        724313  Emissions (CO2eq) from N2O (AR5)       6991
#
#                               Item  Year Code  Year  Source Code      Source  \
# 0  Agrifood Systems Waste Disposal       2010  2010         3050  FAO TIER 1
# 1  Agrifood Systems Waste Disposal       2010  2010         3050  FAO TIER 1
# 2  Agrifood Systems Waste Disposal       2010  2010         3050  FAO TIER 1
# 3  Agrifood Systems Waste Disposal       2010  2010         3050  FAO TIER 1
# 4  Agrifood Systems Waste Disposal       2010  2010         3050  FAO TIER 1
#
#          Unit      Value Flag Flag Description  Note
# 0  kilotonnes    81.4689    E  Estimated value   NaN
# 1  kilotonnes     0.5882    E  Estimated value   NaN
# 2  kilotonnes    36.6037    E  Estimated value   NaN
# 3  kilotonnes  2281.1280    E  Estimated value   NaN
# 4  kilotonnes   155.8749    E  Estimated value   NaN

# %%
# Get column names
data.columns
# Out:
# Index(['ï»¿Domain Code', 'Domain', 'Area Code (M49)', 'Area', 'Element Code',
#        'Element', 'Item Code', 'Item', 'Year Code', 'Year', 'Source Code',
#        'Source', 'Unit', 'Value', 'Flag', 'Flag Description', 'Note'],
#       dtype='object')

# %%
data['Area'].value_counts()
# Out:
# Slovenia                         429
# Lithuania                        429
# Norway                           429
# TÃ¼rkiye                         429
# Albania                          429
#                                 ...
# Falkland Islands (Malvinas)       66
# Guam                              55
# Tokelau                           33
# Netherlands Antilles (former)     11
# Channel Islands                    3
# Name: Area, Length: 232, dtype: int64

# %%
#types of emission
data['Element'].value_counts()
# Out:
# Emissions (CO2eq) (AR5)                 12002
# Emissions (CH4)                         11726
# Emissions (CO2eq) from CH4 (AR5)        11726
# Emissions (N2O)                         11474
# Emissions (CO2eq) from N2O (AR5)        11474
# Emissions (CO2)                          9686
# Emissions (CO2eq) from F-gases (AR5)     3772
# Name: Element, dtype: int64

# %%
#types of Units
data['Unit'].value_counts()
# Out:
# kilotonnes    71860
# Name: Unit, dtype: int64

# %%
# Check the summary statistics of the dataset
data.describe()
# Out:
#        Area Code (M49)   Element Code     Item Code     Year Code  \
# count     71860.000000   71860.000000  71860.000000  71860.000000
# mean        425.657960  395627.028305   6711.428041   2015.003994
# std         253.533703  356769.824593    190.411654      3.160812
# min           4.000000    7225.000000   6506.000000   2010.000000
# 25%         204.000000    7230.000000   6508.000000   2012.000000
# 50%         417.000000  717815.000000   6815.000000   2015.000000
# 75%         643.000000  724313.000000   6818.000000   2018.000000
# max         894.000000  724413.000000   6991.000000   2020.000000
#
#                Year  Source Code          Value  Note
# count  71860.000000      71860.0   71860.000000   0.0
# mean    2015.003994       3050.0    2100.388233   NaN
# std        3.160812          0.0   15718.731957   NaN
# min     2010.000000       3050.0       0.000000   NaN
# 25%     2012.000000       3050.0       0.116900   NaN
# 50%     2015.000000       3050.0       7.612100   NaN
# 75%     2018.000000       3050.0     256.663125   NaN
# max     2020.000000       3050.0  500501.123700   NaN

# %%
# Check the information about the dataset, including data types and missing values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71860 entries, 0 to 71859
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ï»¿Domain Code    71860 non-null  object
#  1   Domain            71860 non-null  object
#  2   Area Code (M49)   71860 non-null  int64
#  3   Area              71860 non-null  object
#  4   Element Code      71860 non-null  int64
#  5   Element           71860 non-null  object
#  6   Item Code         71860 non-null  int64
#  7   Item              71860 non-null  object
#  8   Year Code         71860 non-null  int64
#  9   Year              71860 non-null  int64
#  10  Source Code       71860 non-null  int64
#  11  Source            71860 non-null  object
#  12  Unit              71860 non-null  object
#  13  Value             71860 non-null  float64
#  14  Flag              71860 non-null  object
#  15  Flag Description  71860 non-null  object
#  16  Note              0 non-null      float64
# dtypes: float64(2), int64(6), object(9)
# memory usage: 9.3+ MB

# %%
#Maximum emission from
data.sort_values(by=['Value']).tail(5)
# Out:
#       ï»¿Domain Code            Domain  Area Code (M49)             Area  \
# 14629             GT  Emissions totals              156  China, mainland
# 13567             GT  Emissions totals              159            China
# 14635             GT  Emissions totals              156  China, mainland
# 13573             GT  Emissions totals              159            China
# 13579             GT  Emissions totals              159            China
#
#        Element Code                  Element  Item Code   Item  Year Code  \
# 14629        723113  Emissions (CO2eq) (AR5)       6818  Waste       2019
# 13567        723113  Emissions (CO2eq) (AR5)       6818  Waste       2018
# 14635        723113  Emissions (CO2eq) (AR5)       6818  Waste       2020
# 13573        723113  Emissions (CO2eq) (AR5)       6818  Waste       2019
# 13579        723113  Emissions (CO2eq) (AR5)       6818  Waste       2020
#
#        Year  Source Code      Source        Unit        Value Flag  \
# 14629  2019         3050  FAO TIER 1  kilotonnes  471266.0000    E
# 13567  2018         3050  FAO TIER 1  kilotonnes  477624.6403    E
# 14635  2020         3050  FAO TIER 1  kilotonnes  483100.0000    E
# 13573  2019         3050  FAO TIER 1  kilotonnes  489613.3908    E
# 13579  2020         3050  FAO TIER 1  kilotonnes  500501.1237    E
#
#       Flag Description  Note
# 14629  Estimated value   NaN
# 13567  Estimated value   NaN
# 14635  Estimated value   NaN
# 13573  Estimated value   NaN
# 13579  Estimated value   NaN

# %%
# Top CH4 emissions
ch4_data = data[data['Element'] == 'Emissions (CH4)']

ch4_by_country = ch4_data.groupby('Area')['Value'].sum()

# top 10 countries
top_10_ch4_countries = ch4_by_country.sort_values(ascending=False).head(10)

# Plot a horizontal bar
plt.barh(top_10_ch4_countries.index, top_10_ch4_countries)
plt.xlabel('CH4 Emissions')
plt.ylabel('Country')
plt.title('Top 10 CH4 Emissions by Country')
plt.show()

# %%
# Top CH4 emissions
ch4_data = data[data['Element'] == 'Emissions (CO2eq) (AR5)']

ch4_by_country = ch4_data.groupby('Area')['Value'].sum()

# top 10 countries
top_10_ch4_countries = ch4_by_country.sort_values(ascending=False).head(10)

# Plot a horizontal bar
plt.barh(top_10_ch4_countries.index, top_10_ch4_countries)
plt.xlabel('CO2eq Emissions')
plt.ylabel('Country')
plt.title('Top 10 CO2eq Emissions by Country')
plt.show()

# %%
#types of items emission wise
item_counts = data['Item'].value_counts()

# Plot a histogram of the item counts
plt.bar(item_counts.index, item_counts)
plt.xlabel('Item')
plt.ylabel('Count')
plt.title('Item Emission Counts')
plt.xticks(rotation=90)
plt.show()

# %%
# Check for missing values
print(data.isnull().sum())

# Handle missing values
# Option 1: Remove rows with missing values
data = data.dropna()
# Out:
# ï»¿Domain Code          0
# Domain                  0
# Area Code (M49)         0
# Area                    0
# Element Code            0
# Element                 0
# Item Code               0
# Item                    0
# Year Code               0
# Year                    0
# Source Code             0
# Source                  0
# Unit                    0
# Value                   0
# Flag                    0
# Flag Description        0
# Note                71860
# dtype: int64
